# %% [markdown]
# # Lab | Data Structures

# %% [markdown]
# ## Exercise: Managing Customer Orders
#
# As part of a business venture, you are starting an online store that sells various products. To ensure smooth operations, you need to develop a program that manages customer orders and inventory.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a list called `products` that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".
#
# 2. Create an empty dictionary called `inventory`.
#
# 3. Ask the user to input the quantity of each product available in the inventory. Use the product names from the `products` list as keys in the `inventory` dictionary and assign the respective quantities as values.
#
# 4. Create an empty set called `customer_orders`.
#
# 5. Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the `customer_orders` set.
#
# 6. Print the products in the `customer_orders` set.
#
# 7. Calculate the following order statistics:
#    - Total Products Ordered: The total number of products in the `customer_orders` set.
#    - Percentage of Products Ordered: The percentage of products ordered compared to the total available products.
#
#    Store these statistics in a tuple called `order_status`.
#
# 8. Print the order statistics using the following format:
#    ```
#    Order Statistics:
#    Total Products Ordered: <total_products_ordered>
#    Percentage of Products Ordered: <percentage_ordered>%
#    ```
#
# 9. Update the inventory by subtracting 1 from the quantity of each product. Modify the `inventory` dictionary accordingly.
#
# 10. Print the updated inventory, displaying the quantity of each product on separate lines.
#
# Solve the exercise by implementing the steps using the Python concepts of lists, dictionaries, sets, and basic input/output operations.

# %%
products = ["t-shirt", "mug", "hat", "book", "keychain"]
inventory = {}

for elements in products:
    values = int(input (f"How many {elements} do you have? "))
    inventory[elements] = values
print(inventory)

customer_orders = set()
customer_orders.add(input ('Name one product out of "t-shirt", "mug", "hat", "book" or "keychain". You can only choose one of each item per order:'))
customer_orders.add(input ('Name one product out of "t-shirt", "mug", "hat", "book" or "keychain". You can only choose one of each item per order:'))
customer_orders.add(input ('Name one product out of "t-shirt", "mug", "hat", "book" or "keychain". You can only choose one of each item per order:'))
print(customer_orders)

# they can only choose one per order, so I can use a set without overwriting it. It is for the purpose of the exercise.

total_order = len(customer_orders)
for product in customer_orders:
    percentage_order = (1 / inventory[product]) * 100
    print("The percentage of", product, "compared to the total available products is ", percentage_order)

total_inventory = 0
for key in inventory:
    sum_inventory = inventory[key]
    total_inventory += sum_inventory
percentage_order_total = (len(customer_orders) / total_inventory) * 100
order_status = (total_order, percentage_order_total)

print (f"""Order Statistics:
Total Products Ordered: {order_status[0]}
Percentage of Products Ordered: {order_status[1]} % """)

for elements in inventory:
    old_value = inventory[elements]
    new_value = old_value - 1
    inventory[elements] = new_value


for keys, values in inventory.items():
    print (f"You have {values}, {keys}")
# Out:
# How many t-shirt do you have?  10
# How many mug do you have?  20
# How many hat do you have?  30
# How many book do you have?  40
# How many keychain do you have?  50
# {'t-shirt': 10, 'mug': 20, 'hat': 30, 'book': 40, 'keychain': 50}
# Name one product out of "t-shirt", "mug", "hat", "book" or "keychain". You can only choose one of each item per order: mug
# Name one product out of "t-shirt", "mug", "hat", "book" or "keychain". You can only choose one of each item per order: hat
# Name one product out of "t-shirt", "mug", "hat", "book" or "keychain". You can only choose one of each item per order: book
# {'hat', 'book', 'mug'}
# The percentage of hat compared to the total available products is  3.3333333333333335
# The percentage of book compared to the total available products is  2.5
# The percentage of mug compared to the total available products is  5.0
# Order Statistics:
# Total Products Ordered: 3
# Percentage of Products Ordered: 2.0 %
# You have 9, t-shirt
# You have 19, mug
# You have 29, hat
# You have 39, book
# You have 49, keychain
